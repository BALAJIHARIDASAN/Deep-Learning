# %% [markdown]
# <a href="https://colab.research.google.com/github/BALAJIHARIDASAN/Deep-Learning/blob/main/Deep_Learning_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Rule-based Expert System**
#
# A rule-based expert system is the simplest form of artificial intelligence and uses prescribed knowledge-based rules to solve a problem. The objective of an expert system is to take knowledge from a human expert and convert this into a number of well defined rules to apply explicitly to the input data.
#
# In the most basic form, the rules are commonly conditional statements (if a, then x, else if b, then y). These systems should be applied to smaller problems. It is mainly because the more complex a system is, the more rules that are required to describe it, and thus increased difficulty to define all the rules for all possible outcomes.

# %%
def AndGate(A, B):
    if A == 0:
        if B == 0:
            C = 0
        elif B == 1:
            C = 0
    elif A == 1:
        if B == 0:
            C = 0
        elif B == 1:
            C =1
    return C

# %%
print(AndGate(0,0))
print(AndGate(0,1))
print(AndGate(1,0))
print(AndGate(1,1))
# Out:
# 0
# 0
# 0
# 1

# %% [markdown]
# **Machine Learning**
#
# Machine learning is an application of artificial intelligence that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. Machine learning focuses on the development of computer programs that can access data and use it to learn for themselves.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

X=np.array([[0, 0], 
            [0, 1],
            [1, 0], 
            [1, 1]])

y=np.array([0, 0, 0, 1]).reshape(4,1)

# %%
model = Sequential()
model.add(Dense(4, input_shape=(X.shape[1],)))
model.add(Dense(1, activation ='sigmoid'))
model.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X, y, epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 863ms/step - loss: 0.7967 - accuracy: 0.7500
# Epoch 2/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7920 - accuracy: 0.7500
# Epoch 3/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7886 - accuracy: 0.7500
# Epoch 4/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7858 - accuracy: 0.7500
# Epoch 5/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7833 - accuracy: 0.7500
# Epoch 6/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7810 - accuracy: 0.7500
# Epoch 7/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7789 - accuracy: 0.7500
# Epoch 8/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7769 - accuracy: 0.7500
# Epoch 9/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7750 - accuracy: 0.7500
# Epoch 10/200
# ...

# %%
Loss, Acc = model.evaluate(X, y, verbose=0)
print('The accuracy is:', Acc*100, '%')
# Out:
# The accuracy is: 75.0 %

# %%
X=np.array([[0, 0], 
            [0, 1],
            [1, 0], 
            [1, 1]])

y=np.array([0, 0, 0, 1]).reshape(4,1)

X_new = np.repeat(X, 50, axis=0)
y_new = np.repeat(y, 50, axis=0)

# %%
model = Sequential()
model.add(Dense(4, input_shape=(X.shape[1],)))
model.add(Dense(1, activation ='sigmoid'))
model.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_new, y_new, epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 3ms/step - loss: 0.9438 - accuracy: 0.5000
# Epoch 2/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9099 - accuracy: 0.5000
# Epoch 3/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8861 - accuracy: 0.5000
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8662 - accuracy: 0.5000
# Epoch 5/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8470 - accuracy: 0.5000
# Epoch 6/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8282 - accuracy: 0.5000
# Epoch 7/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8089 - accuracy: 0.5000
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7924 - accuracy: 0.5000
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7756 - accuracy: 0.5000
# Epoch 10/100
# ...

# %%
Loss_new, Acc_new = model.evaluate(X_new, y_new, verbose=0)
print('The accuracy is:', Acc_new*100, '%')
# Out:
# The accuracy is: 100.0 %

# %% [markdown]
#   With large enough data, not only the accuracy is higher, but also the convergence rate is faster.
